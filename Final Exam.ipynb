# %% [markdown]
# # My Jupyter Noteboon on IBM Watson Studio

# %% [markdown]
# __Jesus Guadalupe Medina Alanis__

# %% [markdown]
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I would love to help organizations to develop useful insights using Data Science_

# %% [markdown]
# ### The following cell should do the sum of 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ### Numbered List
#
# 1. One Item
# 2. Another Item
# 3. Just Another Item
# 4. Another more
#
# ************
#
# ### Table
#
# |   1   |   2   |   3   |
# |-------|-------|-------|
# |  uno  |  dos  |  tres |
# | pa    |   pe  |  pi   |
# | po    |   pu  |  pa   |
#
# -------------
#
# ### Hyperlink
#
# [Google's Home Page](https://www.google.com "Google's Homepage")
